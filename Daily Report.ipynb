# %% [markdown]
# # Daily report
#
# Save the transactions from database files to csv files and generate a daily report.

# %%
import numpy as np
import pandas as pd
import sqlite3
from datetime import datetime

# %%
# connect the sqlite3 database
db = sqlite3.connect('products.db')
cursor = db.cursor()

# import the data from transactions record table of the database and convert the time into datetime
transactions = pd.read_sql_query(('SELECT * FROM t_record'), db)
transactions.time = pd.to_datetime(transactions.time)

# %%
display(transactions)
# Out:
#     transationid                time                         productname  \
# 0              1 2017-12-13 11:38:37                     Small Americano
# 1              1 2017-12-13 11:38:37          Kettle Chips Lighly Salted
# 2              1 2017-12-13 11:38:37                         Small Latte
# 3              2 2017-12-13 11:38:49                     Coca Cola 330ml
# 4              2 2017-12-13 11:38:49                         Large Mocha
# 5              2 2017-12-13 11:38:49                    Sea Salt Popcorn
# 6              2 2017-12-13 11:38:49                   Medium Cappuccino
# 7              3 2017-12-13 11:39:03                         Small Latte
# 8              3 2017-12-13 11:39:03                     Coca Cola 330ml
# 9              3 2017-12-13 11:39:03              Panini Roast Beef Melt
# 10             4 2017-12-13 11:39:28                     Coca Cola 330ml
# 11             4 2017-12-13 11:39:28                         Large Mocha
# 12             4 2017-12-13 11:39:28      Kettle Chips Cheddar and Onion
# 13             4 2017-12-13 11:39:28              Panini Roast Beef Melt
# 14             5 2017-12-13 11:39:45                        Medium Latte
# 15             5 2017-12-13 11:39:45                   Medium Cappuccino
# 16             5 2017-12-13 11:39:45          Kettle Chips Lighly Salted
# 17             6 2017-12-13 11:40:06                        Medium Mocha
# 18             6 2017-12-13 11:40:06             Sandwich Ham and Pickle
# 19             6 2017-12-13 11:40:06                    Small Cappuccino
# 20             7 2017-12-13 11:40:26                     Coca Cola 330ml
# 21             7 2017-12-13 11:40:26                Oat and Rasin Cookie
# 22             7 2017-12-13 11:40:26              Panini Roast Beef Melt
# 23             8 2017-12-13 11:40:33                     Coca Cola 330ml
# 24             8 2017-12-13 11:40:33              Panini Roast Beef Melt
# 25             8 2017-12-13 11:40:33             Triple Chocolate Cookie
# 26             9 2017-12-13 11:41:22                         Small Latte
# 27             9 2017-12-13 11:41:22                    Small Cappuccino
# 28             9 2017-12-13 11:41:22             Sandwich Ham and Cheese
# 29            10 2017-12-13 11:41:32                         Large Latte
# ..           ...                 ...                                 ...
# 38            13 2017-12-13 11:42:48                      Piece of Fruit
# 39            14 2017-12-13 11:42:57                     Coca Cola 330ml
# 40            14 2017-12-13 11:42:57                Medium Hot Chocolate
# 41            14 2017-12-13 11:42:57              Panini Roast Beef Melt
# 42            15 2017-12-13 11:44:04                     Coca Cola 330ml
# 43            15 2017-12-13 11:44:04                    Salad Greek Feta
# 44            15 2017-12-13 11:44:04              Panini Roast Beef Melt
# 45            16 2017-12-13 11:44:14                         Small Latte
# 46            18 2017-12-13 11:44:48                     Coke Zero 330ml
# 47            18 2017-12-13 11:44:48                         Small Latte
# 48            18 2017-12-13 11:44:48                        Medium Mocha
# 49            19 2017-12-13 11:46:55                     Coca Cola 330ml
# 50            19 2017-12-13 11:46:55                         Small Latte
# 51            19 2017-12-13 11:46:55              Panini Roast Beef Melt
# 52            20 2017-12-13 11:48:06                     Coke Zero 330ml
# 53            20 2017-12-13 11:48:06                    Sea Salt Popcorn
# 54            23 2017-12-13 11:48:43                         Small Latte
# 55            23 2017-12-13 11:48:43                   Medium Cappuccino
# 56            24 2017-12-13 11:49:10                      Lemonade 330ml
# 57            24 2017-12-13 11:49:10                         Small Latte
# 58            24 2017-12-13 11:49:10                   Medium Cappuccino
# 59            25 2017-12-13 11:49:18                         Small Latte
# 60            25 2017-12-13 11:49:18       Panini Bacon, Brie, Cranberry
# 61            25 2017-12-13 11:49:18                Oat and Rasin Cookie
# 62            25 2017-12-13 11:49:18                   Medium Cappuccino
# 63            26 2017-12-13 11:49:27                     Coca Cola 330ml
# 64            26 2017-12-13 11:49:27  Kettle Chips Sea Salt and Balsamic
# 65            26 2017-12-13 11:49:27              Panini Roast Beef Melt
# 66            27 2017-12-13 11:49:30                 Salad Mezze Platter
# 67            27 2017-12-13 11:49:30              Sandwich Chicken Tikka
#
#     productid  amount methodname
# 0          14       1     Credit
# 1          72       1     Credit
# 2          15       1     Credit
# 3          38       1      Debit
# 4          29       1      Debit
# 5          65       1      Debit
# 6           4       1      Debit
# 7          15       1       Cash
# 8          38       1       Cash
# 9          44       1       Cash
# 10         38       1     Credit
# 11         29       1     Credit
# 12         70       1     Credit
# 13         44       1     Credit
# 14          3       1      Debit
# 15          4       1      Debit
# 16         72       1      Debit
# 17          5       1       Cash
# 18         53       1       Cash
# 19         16       1       Cash
# 20         38       1      Debit
# 21         67       1      Debit
# 22         44       1      Debit
# 23         38       1       Cash
# 24         44       1       Cash
# 25         68       1       Cash
# 26         15       1     Credit
# 27         16       1     Credit
# 28         54       1     Credit
# 29         27       1       Cash
# ..        ...     ...        ...
# 38         69       1      Debit
# 39         38       1       Cash
# 40          6       1       Cash
# 41         44       1       Cash
# 42         38       1     Credit
# 43         52       1     Credit
# 44         44       1     Credit
# 45         15       1       Cash
# 46         39       1       Cash
# 47         15       1       Cash
# 48          5       1       Cash
# 49         38       1       Cash
# 50         15       1       Cash
# 51         44       1       Cash
# 52         39       1     Credit
# 53         65       1     Credit
# 54         15       1      Debit
# 55          4       1      Debit
# 56         40       1     Credit
# 57         15       1     Credit
# 58          4       1     Credit
# 59         15       1       Cash
# 60         48       1       Cash
# 61         67       1       Cash
# 62          4       1       Cash
# 63         38       1      Debit
# 64         71       1      Debit
# 65         44       1      Debit
# 66         51       1     Credit
# 67         58       1     Credit
#
# [68 rows x 6 columns]

# %%
# define a function that used to select a day
def select_time(dataframe, d, m, y):
    daily_transactions = dataframe[(dataframe.time.dt.day == d) & (dataframe.time.dt.month == m) 
                                   & (dataframe.time.dt.year == y)]
    
    return daily_transactions

# %%
# define a function that used to calculate the amounts of each method
def method_counts(data):
    cash = 0
    debit = 0
    credit = 0
    for i in data:
        if i == 'Cash':
            cash += 1
        if i == 'Debit':
            debit += 1
        if i == 'Credit':
            credit += 1
    
    return cash, debit, credit

# %%
# define a function that make a daily report
def report(dataframe, d, m, y):  
    
    dataframe = select_time(dataframe, d, m, y)
    
    mask = np.array(dataframe.productid)
    product_id, counts = np.unique(mask, return_counts = True)

    product_name = []
    product_price = []
    total_value = []
    total_cash = []
    total_debit = []
    total_credit = []

    for i in range(len(product_id)):
        cursor.execute('SELECT price FROM products WHERE productid = ?', (int(product_id[i]),))
        product_price.append(cursor.fetchone()[0] / 100)
        product_name.append(list(dataframe.loc[dataframe.productid == product_id[i]]['productname'])[0])  
        total_value.append(float("{0:.2f}".format(product_price[i] * counts[i])))
        method = list(dataframe.loc[dataframe.productid == product_id[i]]['methodname'])
        method = method_counts(method)
        total_cash.append(method[0])
        total_debit.append(method[1])
        total_credit.append(method[2])

    column_name = ['product_name', 'product_id','product_price', 'sales_counts','sales_values', 
                   'Paid by Cash amounts', 'Paid by Debit amounts', 'Paid by Credit amounts']

    w_values = np.column_stack((product_name, product_id, product_price, counts, total_value, 
                                total_cash, total_debit, total_credit))

    report = pd.DataFrame(columns = column_name,data = w_values)
    
    return report

# %%
# for example, report the transactions daily report on 2017/12/13
daily_20171213 = report(transactions, 13, 12, 2017)

# %%
display(daily_20171213)
# Out:
#                           product_name product_id product_price sales_counts  \
# 0                         Medium Latte          3           2.0            1
# 1                    Medium Cappuccino          4           2.0            5
# 2                         Medium Mocha          5           2.2            2
# 3                 Medium Hot Chocolate          6           2.1            1
# 4                      Small Americano         14           1.6            1
# 5                          Small Latte         15           1.8           10
# 6                     Small Cappuccino         16           1.8            2
# 7                          Large Latte         27          2.25            1
# 8                          Large Mocha         29           2.6            2
# 9                      Coca Cola 330ml         38           1.0           11
# 10                     Coke Zero 330ml         39           1.0            2
# 11                      Lemonade 330ml         40           1.0            1
# 12              Panini Roast Beef Melt         44          4.75           10
# 13       Panini Bacon, Brie, Cranberry         48          4.75            1
# 14                          Salad Tuna         50          5.95            1
# 15                 Salad Mezze Platter         51          5.95            1
# 16                    Salad Greek Feta         52          5.95            1
# 17             Sandwich Ham and Pickle         53          3.49            1
# 18             Sandwich Ham and Cheese         54          3.49            2
# 19              Sandwich Chicken Tikka         58          3.45            1
# 20                    Sea Salt Popcorn         65          0.65            3
# 21                Oat and Rasin Cookie         67          0.65            2
# 22             Triple Chocolate Cookie         68          0.65            1
# 23                      Piece of Fruit         69           0.5            1
# 24      Kettle Chips Cheddar and Onion         70          0.85            1
# 25  Kettle Chips Sea Salt and Balsamic         71          0.85            1
# 26          Kettle Chips Lighly Salted         72          0.85            2
#
#    sales_values Paid by Cash amounts Paid by Debit amounts  \
# 0           2.0                    0                     1
# 1          10.0                    1                     3
# 2           4.4                    2                     0
# 3           2.1                    1                     0
# 4           1.6                    0                     0
# 5          18.0                    5                     1
# 6           3.6                    1                     0
# 7          2.25                    1                     0
# 8           5.2                    0                     1
# 9          11.0                    5                     4
# 10          2.0                    1                     0
# 11          1.0                    0                     0
# 12         47.5                    5                     3
# 13         4.75                    1                     0
# 14         5.95                    0                     0
# 15         5.95                    0                     0
# 16         5.95                    0                     0
# 17         3.49                    1                     0
# 18         6.98                    0                     0
# 19         3.45                    0                     0
# 20         1.95                    0                     2
# 21          1.3                    1                     1
# 22         0.65                    1                     0
# 23          0.5                    0                     1
# 24         0.85                    0                     0
# 25         0.85                    0                     1
# 26          1.7                    0                     1
#
#    Paid by Credit amounts
# 0                       0
# 1                       1
# 2                       0
# 3                       0
# 4                       1
# 5                       4
# 6                       1
# 7                       0
# 8                       1
# 9                       2
# 10                      1
# 11                      1
# 12                      2
# 13                      0
# 14                      1
# 15                      1
# 16                      1
# 17                      0
# 18                      2
# 19                      1
# 20                      1
# 21                      0
# 22                      0
# 23                      0
# 24                      1
# 25                      0
# 26                      1

# %%
# define a function that used to report a target product during the period
def product_report(dataframe, target_product_id, start_datetime, end_datetime):
    start_datetime = pd.to_datetime(start_datetime)
    end_datetime = pd.to_datetime(end_datetime)
    
    # select the target product dataframe
    product_data = dataframe.loc[dataframe.productid == target_product_id]
    
    # select the period dataframe
    product_data = product_data.loc[(product_data.time > start_datetime) & (product_data.time < end_datetime)]
    
    # insert the date used for group by
    product_data.insert(6, 'date', product_data.time.dt.date, allow_duplicates=False)
    
    # insert the price
    cursor.execute('SELECT price FROM products WHERE productid = ?', (target_product_id,))
    target_price = cursor.fetchone()[0] / 100
    product_data.insert(7, 'price', target_price, allow_duplicates=False)
    
    # group by
    product_report = product_data.groupby(['date','productname'])['amount', 'price'].sum()
    
    product_report = product_report.rename(index = str, 
                                           columns = {'amount': 'total_volume', 'price': 'total_value'})
    
    product_report.reset_index(level=(0,1), inplace=True)

    return product_report

# %%
# for example, select productid == 38 for the following time period
start_time = '13-12-2017 11:41:00'
end_time = '13-12-2017 11:46:00'
target_product_id = 38

report_38 = product_report(transactions, target_product_id, start_time, end_time)

# %%
display(report_38)
# Out:
#          date      productname  total_volume  total_value
# 0  2017-12-13  Coca Cola 330ml             4          4.0

# %%
# export the data into csv files
transactions.to_csv('till_tansactions.csv', encoding = 'utf-8', index = False)

daily_20171213.to_csv('Daily_report_20171213.csv', encoding = 'utf-8', index = False)

report_38.to_csv('Product_report_38.csv', encoding = 'utf-8', index = False)
